# %% [markdown]
# # 6.0 Introduction RAG (04:20)

# %% [markdown]
# # 6.1 Data Loaders and Splitters (14:35)

# %%
from dotenv import load_dotenv
load_dotenv()

from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import TextLoader

loader = TextLoader("./files/chapter_one.txt")

loader.load()
# Out:
# [Document(page_content="Part 1, Chapter 1\n\nPart One\n\n\n1\nIt was a bright cold day in April, and the clocks were striking thirteen. Winston Smith, his chin nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory Mansions, though not quickly enough to prevent a swirl of gritty dust from entering along with him.\n\nThe hallway smelt of boiled cabbage and old rag mats. At one end of it a coloured poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you about when you move. BIG BROTHER IS WATCHING YOU, the caption beneath it ran.\n\nInside the flat a fruity voice was reading out a list of figures which had something to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it off completely. He moved over to the window: a smallish, frail figure, the meagreness of his body merely emphasized by the blue overalls which were the uniform of the party. His hair was very fair, his face naturally sanguine, his skin roughened by coarse soap and blunt razor blades and the cold of the winter that had just ended.\n\nOutside, even through the shut window-pane, the world looked cold. Down in the street little eddies of wind were whirling dust and torn paper into spirals, and though the sun was shining and the sky a harsh blue, there seemed to be no colour in anything, except the posters that were plastered everywhere. The blackmoustachio'd face gazed down from every commanding corner. There was one on the house-front immediately opposite. BIG BROTHER IS WATCHING YOU, the caption said, while the dark eyes looked deep into Winston's own. Down at streetlevel another poster, torn at one corner, flapped fitfully in the wind, alternately covering and uncovering the single word INGSOC. In the far distance a helicopter skimmed down between the roofs, hovered for an instant like a bluebottle, and darted away again with a curving flight. It was the police patrol, snooping into people's windows. The patrols did not matter, however. Only the Thought Police mattered.\n\nBehind Winston's back the voice from the telescreen was still babbling away about pig-iron and the overfulfilment of the Ninth Three-Year Plan. The telescreen received and transmitted simultaneously. Any sound that Winston made, above the level of a very low whisper, would be picked up by it, moreover, so long as he remained within the field of vision which the metal plaque commanded, he could be seen as well as heard. There was of course no way of knowing whether you were being watched at any given moment. How often, or on what system, the Thought Police plugged in on any individual wire was guesswork. It was even conceivable that they watched everybody all the time. But at any rate they could plug in your wire whenever they wanted to. You had to live -- did live, from habit that became instinct -- in the assumption that every sound you made was overheard, and, except in darkness, every movement scrutinized ...

# %%
from dotenv import load_dotenv
load_dotenv()

from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader


loader = UnstructuredFileLoader("./files/chapter_one.pdf")

loader.load()
# Out:
# [Document(page_content="Part 1, Chapter 1\n\nPart One\n\n1 It was a bright cold day in April, and the clocks were striking thirteen. Winston Smith, his chin nuzzled into his breast in an eﬀort to escape the vile wind, slipped quickly through the glass doors of Victory Mansions, though not quickly enough to prevent a swirl of gritty dust from entering along with him.\n\nThe hallway smelt of boiled cabbage and old rag mats. At one end of it a coloured poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-ﬁve, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at present the electric current was cut oﬀ during daylight hours. It was part of the economy drive in preparation for Hate Week. The ﬂat was seven ﬂights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you about when you move. BIG BROTHER IS WATCHING YOU, the caption beneath it ran.\n\nInside the ﬂat a fruity voice was reading out a list of ﬁgures which had something to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it oﬀ completely. He moved over to the window: a smallish, frail ﬁgure, the meagreness of his body merely emphasized by the blue overalls which were the uniform of the party. His hair was very fair, his face naturally sanguine, his skin roughened by coarse soap and blunt razor blades and the cold of the winter that had just ended.\n\nOutside, even through the shut window-pane, the world looked cold. Down in the street little eddies of wind were whirling dust and torn paper into spirals, and though the sun was shining and the sky a harsh blue, there seemed to be no colour in anything, except the posters that were plastered everywhere. The blackmoustachio'd face gazed down from every commanding corner. There was one on the house-front immediately opposite. BIG BROTHER IS WATCHING YOU, the caption said, while the dark eyes looked deep into Winston's own. Down at streetlevel another poster, torn at one corner, ﬂapped ﬁtfully in the wind, alternately covering and uncovering the single word INGSOC. In the far distance a helicopter skimmed down between the roofs, hovered for an instant like a bluebottle, and darted away again with a curving ﬂight. It was the police patrol, snooping into people's windows. The patrols did not matter, however. Only the Thought Police mattered.\n\nBehind Winston's back the voice from the telescreen was still babbling away about pig-iron and the overfulﬁlment of the Ninth Three-Year Plan. The telescreen received and transmitted simultaneously. Any sound that Winston made, above the level of a very low whisper, would be picked up by it, moreover, so long as he remained within the ﬁeld of vision which the metal plaque commanded, he could be seen as well as heard. There was of course no way of knowing whether you were being watched at any given moment. How often, or on what system, the Thought Police plugged in on any individual wire was guesswork. It was even conceivable that they watched everybody all the time. But at any rate they could plug in your wire whenever they wanted to. You had to live -- did live, from habit that became instinct -- in the assumption that every sound you made was overheard, and, except in darkness, every movement scrutinized.\n\n1 / 9\n\nWin ...

# %%
from dotenv import load_dotenv
load_dotenv()

from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader


loader = UnstructuredFileLoader("./files/chapter_one.txt")

loader.load()
# Out:
# [Document(page_content="Part 1, Chapter 1\n\nPart One\n\n1 It was a bright cold day in April, and the clocks were striking thirteen. Winston Smith, his chin nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory Mansions, though not quickly enough to prevent a swirl of gritty dust from entering along with him.\n\nThe hallway smelt of boiled cabbage and old rag mats. At one end of it a coloured poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you about when you move. BIG BROTHER IS WATCHING YOU, the caption beneath it ran.\n\nInside the flat a fruity voice was reading out a list of figures which had something to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it off completely. He moved over to the window: a smallish, frail figure, the meagreness of his body merely emphasized by the blue overalls which were the uniform of the party. His hair was very fair, his face naturally sanguine, his skin roughened by coarse soap and blunt razor blades and the cold of the winter that had just ended.\n\nOutside, even through the shut window-pane, the world looked cold. Down in the street little eddies of wind were whirling dust and torn paper into spirals, and though the sun was shining and the sky a harsh blue, there seemed to be no colour in anything, except the posters that were plastered everywhere. The blackmoustachio'd face gazed down from every commanding corner. There was one on the house-front immediately opposite. BIG BROTHER IS WATCHING YOU, the caption said, while the dark eyes looked deep into Winston's own. Down at streetlevel another poster, torn at one corner, flapped fitfully in the wind, alternately covering and uncovering the single word INGSOC. In the far distance a helicopter skimmed down between the roofs, hovered for an instant like a bluebottle, and darted away again with a curving flight. It was the police patrol, snooping into people's windows. The patrols did not matter, however. Only the Thought Police mattered.\n\nBehind Winston's back the voice from the telescreen was still babbling away about pig-iron and the overfulfilment of the Ninth Three-Year Plan. The telescreen received and transmitted simultaneously. Any sound that Winston made, above the level of a very low whisper, would be picked up by it, moreover, so long as he remained within the field of vision which the metal plaque commanded, he could be seen as well as heard. There was of course no way of knowing whether you were being watched at any given moment. How often, or on what system, the Thought Police plugged in on any individual wire was guesswork. It was even conceivable that they watched everybody all the time. But at any rate they could plug in your wire whenever they wanted to. You had to live -- did live, from habit that became instinct -- in the assumption that every sound you made was overheard, and, except in darkness, every movement scrutinized.\n ...

# %%
len(loader.load())
# Out:
# 1

# %%
from dotenv import load_dotenv
load_dotenv()

from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=200
)
# chunk_size를 기준으로 자르기때문에 문장 중간이 잘린다. 

loader = UnstructuredFileLoader("./files/chapter_one.txt")


loader.load_and_split(text_splitter=splitter)
# Out:
# [Document(page_content='Part 1, Chapter 1\n\nPart One', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='1 It was a bright cold day in April, and the clocks were striking thirteen. Winston Smith, his chin nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='It was a bright cold day in April, and the clocks were striking thirteen. Winston Smith, his chin nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass doors', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='was a bright cold day in April, and the clocks were striking thirteen. Winston Smith, his chin nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='cold day in April, and the clocks were striking thirteen. Winston Smith, his chin nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='day in April, and the clocks were striking thirteen. Winston Smith, his chin nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory Mansions,', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='April, and the clocks were striking thirteen. Winston Smith, his chin nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory Mansions, though', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='and the clocks were striking thirteen. Winston Smith, his chin nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory Mansions, though not', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='clocks were striking thirteen. Winston Smith, his chin nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory Mansions, though not quickly', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='were striking thirteen. Winston Smith, his chin nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory Mansions, though not quickly enough to', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='thirteen. Winston Smith, his chin nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory Mansions, though not quickly enough to prevent a', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='Winston Smith, his chin nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory Mansions, though not quickly enough to prevent a swirl of', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='Smith, his chin nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory Mansions, though not quickly enough to prevent a swirl of gritty dust', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='his chin nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory Mansions, though not quickly enough to prevent a swirl of gritty dust from', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory Mansions, though not quickly enough to prevent a swirl of gritty dust from entering', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory Mansions, though not quickly enough to prevent a swirl of gritty dust from entering along with', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory Mansions, though not quickly enough to prevent a swirl of gritty dust from entering along with him.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='The hallway smelt of boiled cabbage and old rag mats. At one end of it a coloured poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='hallway smelt of boiled cabbage and old rag mats. At one end of it a coloured poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='smelt of boiled cabbage and old rag mats. At one end of it a coloured poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide:', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='of boiled cabbage and old rag mats. At one end of it a coloured poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='boiled cabbage and old rag mats. At one end of it a coloured poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='cabbage and old rag mats. At one end of it a coloured poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='and old rag mats. At one end of it a coloured poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='old rag mats. At one end of it a coloured poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='At one end of it a coloured poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='one end of it a coloured poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='of it a coloured poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='it a coloured poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of times', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working,', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at present', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at present the electric', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at present the electric current', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at present the electric current was', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at present the electric current was cut off', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at present the electric current was cut off during', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at present the electric current was cut off during daylight hours.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='It was no use trying the lift. Even at the best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='was no use trying the lift. Even at the best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='use trying the lift. Even at the best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='trying the lift. Even at the best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='the lift. Even at the best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='lift. Even at the best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='Even at the best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='at the best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='of times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up,', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston,', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle,', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly,', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft,', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you about', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you about when', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you about when you', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you about when you move.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you about when you move. BIG', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you about when you move. BIG BROTHER', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you about when you move. BIG BROTHER IS', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you about when you move. BIG BROTHER IS WATCHING YOU,', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you about when you move. BIG BROTHER IS WATCHING YOU, the', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you about when you move. BIG BROTHER IS WATCHING YOU, the caption', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you about when you move. BIG BROTHER IS WATCHING YOU, the caption beneath', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you about when you move. BIG BROTHER IS WATCHING YOU, the caption beneath it ran.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='Inside the flat a fruity voice was reading out a list of figures which had something to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='the flat a fruity voice was reading out a list of figures which had something to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='flat a fruity voice was reading out a list of figures which had something to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='a fruity voice was reading out a list of figures which had something to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of the', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='voice was reading out a list of figures which had something to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='was reading out a list of figures which had something to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of the', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='out a list of figures which had something to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='a list of figures which had something to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='of figures which had something to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='which had something to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='had something to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a switch', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='something to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a switch and', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a switch and the voice', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a switch and the voice sank', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat,', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='The voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='mirror which formed part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='which formed part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='formed part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called)', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed,', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it off', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it off completely.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it off completely. He', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it off completely. He moved', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it off completely. He moved over', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it off completely. He moved over to', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it off completely. He moved over to the', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it off completely. He moved over to the window:', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it off completely. He moved over to the window: a', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it off completely. He moved over to the window: a smallish,', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it off completely. He moved over to the window: a smallish, frail', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it off completely. He moved over to the window: a smallish, frail figure,', metadata={'source': './files/chapter_one.txt'}),
# ...
#  Document(page_content='the book was much older than that. He had seen it lying in the window of a frowsy little junk-shop in a slummy quarter of the town (just what quarter he did not now remember) and had been stricken', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='was much older than that. He had seen it lying in the window of a frowsy little junk-shop in a slummy quarter of the town (just what quarter he did not now remember) and had been stricken immediately', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='much older than that. He had seen it lying in the window of a frowsy little junk-shop in a slummy quarter of the town (just what quarter he did not now remember) and had been stricken immediately by', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='older than that. He had seen it lying in the window of a frowsy little junk-shop in a slummy quarter of the town (just what quarter he did not now remember) and had been stricken immediately by an', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='that. He had seen it lying in the window of a frowsy little junk-shop in a slummy quarter of the town (just what quarter he did not now remember) and had been stricken immediately by an overwhelming', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='He had seen it lying in the window of a frowsy little junk-shop in a slummy quarter of the town (just what quarter he did not now remember) and had been stricken immediately by an overwhelming desire', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='had seen it lying in the window of a frowsy little junk-shop in a slummy quarter of the town (just what quarter he did not now remember) and had been stricken immediately by an overwhelming desire to', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='it lying in the window of a frowsy little junk-shop in a slummy quarter of the town (just what quarter he did not now remember) and had been stricken immediately by an overwhelming desire to possess', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='lying in the window of a frowsy little junk-shop in a slummy quarter of the town (just what quarter he did not now remember) and had been stricken immediately by an overwhelming desire to possess it.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='in the window of a frowsy little junk-shop in a slummy quarter of the town (just what quarter he did not now remember) and had been stricken immediately by an overwhelming desire to possess it. Party', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='of a frowsy little junk-shop in a slummy quarter of the town (just what quarter he did not now remember) and had been stricken immediately by an overwhelming desire to possess it. Party members were', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='little junk-shop in a slummy quarter of the town (just what quarter he did not now remember) and had been stricken immediately by an overwhelming desire to possess it. Party members were supposed not', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='junk-shop in a slummy quarter of the town (just what quarter he did not now remember) and had been stricken immediately by an overwhelming desire to possess it. Party members were supposed not to go', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='in a slummy quarter of the town (just what quarter he did not now remember) and had been stricken immediately by an overwhelming desire to possess it. Party members were supposed not to go into', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='a slummy quarter of the town (just what quarter he did not now remember) and had been stricken immediately by an overwhelming desire to possess it. Party members were supposed not to go into ordinary', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='quarter of the town (just what quarter he did not now remember) and had been stricken immediately by an overwhelming desire to possess it. Party members were supposed not to go into ordinary shops', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="of the town (just what quarter he did not now remember) and had been stricken immediately by an overwhelming desire to possess it. Party members were supposed not to go into ordinary shops ('dealing", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="the town (just what quarter he did not now remember) and had been stricken immediately by an overwhelming desire to possess it. Party members were supposed not to go into ordinary shops ('dealing on", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="town (just what quarter he did not now remember) and had been stricken immediately by an overwhelming desire to possess it. Party members were supposed not to go into ordinary shops ('dealing on the", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="(just what quarter he did not now remember) and had been stricken immediately by an overwhelming desire to possess it. Party members were supposed not to go into ordinary shops ('dealing on the free", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="quarter he did not now remember) and had been stricken immediately by an overwhelming desire to possess it. Party members were supposed not to go into ordinary shops ('dealing on the free market', it", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="he did not now remember) and had been stricken immediately by an overwhelming desire to possess it. Party members were supposed not to go into ordinary shops ('dealing on the free market', it was", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="not now remember) and had been stricken immediately by an overwhelming desire to possess it. Party members were supposed not to go into ordinary shops ('dealing on the free market', it was called),", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="now remember) and had been stricken immediately by an overwhelming desire to possess it. Party members were supposed not to go into ordinary shops ('dealing on the free market', it was called), but", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="remember) and had been stricken immediately by an overwhelming desire to possess it. Party members were supposed not to go into ordinary shops ('dealing on the free market', it was called), but the", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="and had been stricken immediately by an overwhelming desire to possess it. Party members were supposed not to go into ordinary shops ('dealing on the free market', it was called), but the rule was", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="had been stricken immediately by an overwhelming desire to possess it. Party members were supposed not to go into ordinary shops ('dealing on the free market', it was called), but the rule was not", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="stricken immediately by an overwhelming desire to possess it. Party members were supposed not to go into ordinary shops ('dealing on the free market', it was called), but the rule was not strictly", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="immediately by an overwhelming desire to possess it. Party members were supposed not to go into ordinary shops ('dealing on the free market', it was called), but the rule was not strictly kept,", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="by an overwhelming desire to possess it. Party members were supposed not to go into ordinary shops ('dealing on the free market', it was called), but the rule was not strictly kept, because there", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="an overwhelming desire to possess it. Party members were supposed not to go into ordinary shops ('dealing on the free market', it was called), but the rule was not strictly kept, because there were", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="desire to possess it. Party members were supposed not to go into ordinary shops ('dealing on the free market', it was called), but the rule was not strictly kept, because there were various things,", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="to possess it. Party members were supposed not to go into ordinary shops ('dealing on the free market', it was called), but the rule was not strictly kept, because there were various things, such as", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="it. Party members were supposed not to go into ordinary shops ('dealing on the free market', it was called), but the rule was not strictly kept, because there were various things, such as shoelaces", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="Party members were supposed not to go into ordinary shops ('dealing on the free market', it was called), but the rule was not strictly kept, because there were various things, such as shoelaces and", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="members were supposed not to go into ordinary shops ('dealing on the free market', it was called), but the rule was not strictly kept, because there were various things, such as shoelaces and razor", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="were supposed not to go into ordinary shops ('dealing on the free market', it was called), but the rule was not strictly kept, because there were various things, such as shoelaces and razor blades,", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="supposed not to go into ordinary shops ('dealing on the free market', it was called), but the rule was not strictly kept, because there were various things, such as shoelaces and razor blades, which", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="not to go into ordinary shops ('dealing on the free market', it was called), but the rule was not strictly kept, because there were various things, such as shoelaces and razor blades, which it was", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="into ordinary shops ('dealing on the free market', it was called), but the rule was not strictly kept, because there were various things, such as shoelaces and razor blades, which it was impossible", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="ordinary shops ('dealing on the free market', it was called), but the rule was not strictly kept, because there were various things, such as shoelaces and razor blades, which it was impossible to get", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="shops ('dealing on the free market', it was called), but the rule was not strictly kept, because there were various things, such as shoelaces and razor blades, which it was impossible to get hold of", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="('dealing on the free market', it was called), but the rule was not strictly kept, because there were various things, such as shoelaces and razor blades, which it was impossible to get hold of in any", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="on the free market', it was called), but the rule was not strictly kept, because there were various things, such as shoelaces and razor blades, which it was impossible to get hold of in any other", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="the free market', it was called), but the rule was not strictly kept, because there were various things, such as shoelaces and razor blades, which it was impossible to get hold of in any other way.", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="free market', it was called), but the rule was not strictly kept, because there were various things, such as shoelaces and razor blades, which it was impossible to get hold of in any other way. He", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="market', it was called), but the rule was not strictly kept, because there were various things, such as shoelaces and razor blades, which it was impossible to get hold of in any other way. He had", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='it was called), but the rule was not strictly kept, because there were various things, such as shoelaces and razor blades, which it was impossible to get hold of in any other way. He had given a', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='was called), but the rule was not strictly kept, because there were various things, such as shoelaces and razor blades, which it was impossible to get hold of in any other way. He had given a quick', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='but the rule was not strictly kept, because there were various things, such as shoelaces and razor blades, which it was impossible to get hold of in any other way. He had given a quick glance up and', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='the rule was not strictly kept, because there were various things, such as shoelaces and razor blades, which it was impossible to get hold of in any other way. He had given a quick glance up and down', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='rule was not strictly kept, because there were various things, such as shoelaces and razor blades, which it was impossible to get hold of in any other way. He had given a quick glance up and down the', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='not strictly kept, because there were various things, such as shoelaces and razor blades, which it was impossible to get hold of in any other way. He had given a quick glance up and down the street', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='strictly kept, because there were various things, such as shoelaces and razor blades, which it was impossible to get hold of in any other way. He had given a quick glance up and down the street and', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='kept, because there were various things, such as shoelaces and razor blades, which it was impossible to get hold of in any other way. He had given a quick glance up and down the street and then had', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='because there were various things, such as shoelaces and razor blades, which it was impossible to get hold of in any other way. He had given a quick glance up and down the street and then had slipped', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='there were various things, such as shoelaces and razor blades, which it was impossible to get hold of in any other way. He had given a quick glance up and down the street and then had slipped inside', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='were various things, such as shoelaces and razor blades, which it was impossible to get hold of in any other way. He had given a quick glance up and down the street and then had slipped inside and', metadata={'source': './files/chapter_one.txt'}),
#  ...]

# %%
from dotenv import load_dotenv
load_dotenv()

from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=200,
    chunk_overlap=50,
)
# chunk_size를 기준으로 자르기때문에 문장 중간이 잘린다. 

loader = UnstructuredFileLoader("./files/chapter_one.txt")


loader.load_and_split(text_splitter=splitter)
# Out:
# [Document(page_content='Part 1, Chapter 1\n\nPart One', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='1 It was a bright cold day in April, and the clocks were striking thirteen. Winston Smith, his chin nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='the vile wind, slipped quickly through the glass doors of Victory Mansions, though not quickly enough to prevent a swirl of gritty dust from entering along with him.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='The hallway smelt of boiled cabbage and old rag mats. At one end of it a coloured poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you about when you move. BIG BROTHER IS WATCHING YOU, the caption', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='move. BIG BROTHER IS WATCHING YOU, the caption beneath it ran.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='Inside the flat a fruity voice was reading out a list of figures which had something to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it off completely. He moved over to the window: a', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='it off completely. He moved over to the window: a smallish, frail figure, the meagreness of his body merely emphasized by the blue overalls which were the uniform of the party. His hair was very', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='were the uniform of the party. His hair was very fair, his face naturally sanguine, his skin roughened by coarse soap and blunt razor blades and the cold of the winter that had just ended.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='Outside, even through the shut window-pane, the world looked cold. Down in the street little eddies of wind were whirling dust and torn paper into spirals, and though the sun was shining and the sky', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="and though the sun was shining and the sky a harsh blue, there seemed to be no colour in anything, except the posters that were plastered everywhere. The blackmoustachio'd face gazed down from every", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="The blackmoustachio'd face gazed down from every commanding corner. There was one on the house-front immediately opposite. BIG BROTHER IS WATCHING YOU, the caption said, while the dark eyes looked", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="YOU, the caption said, while the dark eyes looked deep into Winston's own. Down at streetlevel another poster, torn at one corner, flapped fitfully in the wind, alternately covering and uncovering", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='in the wind, alternately covering and uncovering the single word INGSOC. In the far distance a helicopter skimmed down between the roofs, hovered for an instant like a bluebottle, and darted away', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="for an instant like a bluebottle, and darted away again with a curving flight. It was the police patrol, snooping into people's windows. The patrols did not matter, however. Only the Thought Police", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='did not matter, however. Only the Thought Police mattered.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="Behind Winston's back the voice from the telescreen was still babbling away about pig-iron and the overfulfilment of the Ninth Three-Year Plan. The telescreen received and transmitted simultaneously.", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='received and transmitted simultaneously. Any sound that Winston made, above the level of a very low whisper, would be picked up by it, moreover, so long as he remained within the field of vision', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='so long as he remained within the field of vision which the metal plaque commanded, he could be seen as well as heard. There was of course no way of knowing whether you were being watched at any', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='of knowing whether you were being watched at any given moment. How often, or on what system, the Thought Police plugged in on any individual wire was guesswork. It was even conceivable that they', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='was guesswork. It was even conceivable that they watched everybody all the time. But at any rate they could plug in your wire whenever they wanted to. You had to live -- did live, from habit that', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='to. You had to live -- did live, from habit that became instinct -- in the assumption that every sound you made was overheard, and, except in darkness, every movement scrutinized.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='Winston kept his back turned to the telescreen. It was safer, though, as he well knew, even a back can be revealing. A kilometre away the Ministry of Truth, his place of work, towered vast and white', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='Truth, his place of work, towered vast and white above the grimy landscape. This, he thought with a sort of vague distaste -- this was London, chief city of Airstrip One, itself the third most', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='chief city of Airstrip One, itself the third most populous of the provinces of Oceania. He tried to squeeze out some childhood memory that should tell him whether London had always been quite like', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='him whether London had always been quite like this. Were there always these vistas of rotting nineteenth-century houses, their sides shored up with baulks of timber, their windows patched with', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='with baulks of timber, their windows patched with cardboard and their roofs with corrugated iron, their crazy garden walls sagging in all directions? And the bombed sites where the plaster dust', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='And the bombed sites where the plaster dust swirled in the air and the willow-herb straggled over the heaps of rubble; and the places where the bombs had cleared a larger patch and there had sprung', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='had cleared a larger patch and there had sprung up sordid colonies of wooden dwellings like chicken-houses? But it was no use, he could not remember: nothing remained of his childhood except a series', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content
', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='Already! He sat as still as a mouse, in the futile hope that whoever it was might go away after a single attempt. But no, the knocking was repeated. The worst thing of all would be to delay. His', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='The worst thing of all would be to delay. His heart was thumping like a drum, but his face, from long habit, was probably expressionless. He got up and moved heavily towards the door.', metadata={'source': './files/chapter_one.txt'})]

# %%
from dotenv import load_dotenv
load_dotenv()

from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import CharacterTextSplitter

splitter = CharacterTextSplitter(
    separator="\n",
    chunk_size=600,
    chunk_overlap=100,
)
# chunk_size를 기준으로 자르기때문에 문장 중간이 잘린다. 

loader = UnstructuredFileLoader("./files/chapter_one.txt")


loader.load_and_split(text_splitter=splitter)
# Out:
# Created a chunk of size 963, which is longer than the specified 600
# Created a chunk of size 774, which is longer than the specified 600
# Created a chunk of size 954, which is longer than the specified 600
# Created a chunk of size 922, which is longer than the specified 600
# Created a chunk of size 1168, which is longer than the specified 600
# Created a chunk of size 821, which is longer than the specified 600
# Created a chunk of size 700, which is longer than the specified 600
# Created a chunk of size 745, which is longer than the specified 600
# Created a chunk of size 735, which is longer than the specified 600
# Created a chunk of size 1110, which is longer than the specified 600
# Created a chunk of size 991, which is longer than the specified 600
# Created a chunk of size 990, which is longer than the specified 600
# Created a chunk of size 1182, which is longer than the specified 600
# Created a chunk of size 1491, which is longer than the specified 600
# Created a chunk of size 1401, which is longer than the specified 600
# Created a chunk of size 1130, which is longer than the specified 600
# Created a chunk of size 1326, which is longer than the specified 600
# Created a chunk of size 1449, which is longer than the specified 600
# Created a chunk of size 1364, which is longer than the specified 600
# Created a chunk of size 999, which is longer than the specified 600
# Created a chunk of size 930, which is longer than the specified 600
# Created a chunk of size 1022, which is longer than the specified 600
# Created a chunk of size 1260, which is longer than the specified 600
# Created a chunk of size 795, which is longer than the specified 600
# Created a chunk of size 1293, which is longer than the specified 600
# Created a chunk of size 649, which is longer than the specified 600
# [Document(page_content='Part 1, Chapter 1\nPart One\n1 It was a bright cold day in April, and the clocks were striking thirteen. Winston Smith, his chin nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory Mansions, though not quickly enough to prevent a swirl of gritty dust from entering along with him.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='The hallway smelt of boiled cabbage and old rag mats. At one end of it a coloured poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you about when you move. BIG BROTHER IS WATCHING YOU, the caption beneath it ran.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='Inside the flat a fruity voice was reading out a list of figures which had something to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it off completely. He moved over to the window: a smallish, frail figure, the meagreness of his body merely emphasized by the blue overalls which were the uniform of the party. His hair was very fair, his face naturally sanguine, his skin roughened by coarse soap and blunt razor blades and the cold of the winter that had just ended.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="Outside, even through the shut window-pane, the world looked cold. Down in the street little eddies of wind were whirling dust and torn paper into spirals, and though the sun was shining and the sky a harsh blue, there seemed to be no colour in anything, except the posters that were plastered everywhere. The blackmoustachio'd face gazed down from every commanding corner. There was one on the house-front immediately opposite. BIG BROTHER IS WATCHING YOU, the caption said, while the dark eyes looked deep into Winston's own. Down at streetlevel another poster, torn at one corner, flapped fitfully in the wind, alternately covering and uncovering the single word INGSOC. In the far distance a helicopter skimmed down between the roofs, hovered for an instant like a bluebottle, and darted away again with a curving flight. It was the police patrol, snooping into people's windows. The patrols did not matter, however. Only the Thought Police mattered.", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content="Behind Winston's back the voice from the telescreen was still babbling away about pig-iron and the overfulfilment of the Ninth Three-Year Plan. The telescreen received and transmitted simultaneously. Any sound that Winston made, above the level of a very low whisper, would be picked up by it, moreover, so long as he remained within the field of vision which the metal plaque commanded, he could be seen as well as heard. There was of course no way of knowing whether you were being watched at any given moment. How often, or on what system, the Thought Police plugged in on any individual wire was guesswork. It was even conceivable that they watched everybody all the time. But at any rate they could plug in your wire whenever they wanted to. You had to live -- did live, from habit that became instinct -- in the assumption that every sound you made was overheard, and, except in darkness, every movement scrutinized.", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='Winston kept his back turned to the telescreen. It was safer, though, as he well knew, even a back can be revealing. A kilometre away the Ministry of Truth, his place of work, towered vast and white above the grimy landscape. This, he thought with a sort of vague distaste -- this was London, chief city of Airstrip One, itself the third most populous of the provinces of Oceania. He tried to squeeze out some childhood memory that should tell him whether London had always been quite like this. Were there always these vistas of rotting nineteenth-century houses, their sides shored up with baulks of timber, their windows patched with cardboard and their roofs with corrugated iron, their crazy garden walls sagging in all directions? And the bombed sites where the plaster dust swirled in the air and the willow-herb straggled over the heaps of rubble; and the places where the bombs had cleared a larger patch and there had sprung up sordid colonies of wooden dwellings like chicken-houses? But it was no use, he could not remember: nothing remained of his childhood except a series of bright-lit tableaux occurring against no background and mostly unintelligible.', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='The Ministry of Truth -- Minitrue, in Newspeak -- was startlingly different from any other object in sight. It was an enormous pyramidal structure of glittering white concrete, soaring up, terrace after terrace, 300 metres into the air. From where Winston stood it was just possible to read, picked out on its white face in elegant lettering, the three slogans of the Party:\nWAR IS PEACE\nFREEDOM IS SLAVERY\nIGNORANCE IS STRENGTH', metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='
adata={'source': './files/chapter_one.txt'}),
#  Document(page_content="For a moment he was seized by a kind of hysteria. He began writing in a hurried untidy scrawl:\ntheyll shoot me i don't care theyll shoot me in the back of the neck i dont care down with big brother they always shoot you in the back of the neck i dont care down with big brother --\nHe sat back in his chair, slightly ashamed of himself, and laid down the pen. The next moment he started violently. There was a knocking at the door.", metadata={'source': './files/chapter_one.txt'}),
#  Document(page_content='Already! He sat as still as a mouse, in the futile hope that whoever it was might go away after a single attempt. But no, the knocking was repeated. The worst thing of all would be to delay. His heart was thumping like a drum, but his face, from long habit, was probably expressionless. He got up and moved heavily towards the door.', metadata={'source': './files/chapter_one.txt'})]

# %%
len(loader.load_and_split(text_splitter=splitter))
# Out:
# Created a chunk of size 963, which is longer than the specified 600
# Created a chunk of size 774, which is longer than the specified 600
# Created a chunk of size 954, which is longer than the specified 600
# Created a chunk of size 922, which is longer than the specified 600
# Created a chunk of size 1168, which is longer than the specified 600
# Created a chunk of size 821, which is longer than the specified 600
# Created a chunk of size 700, which is longer than the specified 600
# Created a chunk of size 745, which is longer than the specified 600
# Created a chunk of size 735, which is longer than the specified 600
# Created a chunk of size 1110, which is longer than the specified 600
# Created a chunk of size 991, which is longer than the specified 600
# Created a chunk of size 990, which is longer than the specified 600
# Created a chunk of size 1182, which is longer than the specified 600
# Created a chunk of size 1491, which is longer than the specified 600
# Created a chunk of size 1401, which is longer than the specified 600
# Created a chunk of size 1130, which is longer than the specified 600
# Created a chunk of size 1326, which is longer than the specified 600
# Created a chunk of size 1449, which is longer than the specified 600
# Created a chunk of size 1364, which is longer than the specified 600
# Created a chunk of size 999, which is longer than the specified 600
# Created a chunk of size 930, which is longer than the specified 600
# Created a chunk of size 1022, which is longer than the specified 600
# Created a chunk of size 1260, which is longer than the specified 600
# Created a chunk of size 795, which is longer than the specified 600
# Created a chunk of size 1293, which is longer than the specified 600
# Created a chunk of size 649, which is longer than the specified 600
# 45

# %% [markdown]
# # 6.2 Tiktoken (04:19)

# %% [markdown]
# # 6.3 Vectors (11:56)

# %% [markdown]
# # 6.4 Vector Store (12:15)

# %%
from langchain.embeddings import OpenAIEmbeddings

embedder = OpenAIEmbeddings()

embedder.embed_query("Hi")
# Out:
# [-0.03633027945867064,
#  -0.0071502463936614635,
#  -0.033441551486078115,
#  -0.028835205754777587,
#  -0.02680529131815199,
#  0.034352411053515164,
#  -0.012270577419374743,
#  -0.007904958087801004,
#  0.0019209374702995234,
#  -0.002989570651025579,
#  0.024619229473890177,
#  -0.002400765228253544,
#  -0.005657087623047438,
#  -0.002983064664261168,
#  0.006694816609942939,
#  -0.002924509386397588,
#  0.03404011623824273,
#  -0.001470387351277293,
#  0.020936753886571638,
#  -0.009297272317336808,
#  -0.021457245866240742,
#  0.01037078458068254,
#  0.006262158594807118,
#  0.007319405774826498,
#  -0.01225105876058957,
#  0.0008645031602758929,
#  0.005634315854464736,
#  -0.009954392114534362,
#  -0.0030432462641928654,
#  -0.024528142399559368,
#  0.010598499472541802,
#  -0.013884099389852163,
#  -0.024476092642798906,
#  -0.01401422285043073,
#  0.0024186570993093063,
#  -0.01888081457156581,
#  0.00031575104070548496,
#  -0.011366224071532751,
#  0.017865857353253013,
#  -0.017384402691154256,
#  -0.025178756908484454,
#  0.016954997785815964,
#  -0.004638876829275817,
#  -0.02189966321076915,
#  0.012465761213258715,
#  -0.01415735781887683,
#  -0.009837282024468496,
#  -0.012693476105117977,
#  0.012133948670523703,
#  -0.021795563697248225,
#  -0.006844457797984095,
#  0.03643437524690122,
#  -0.017085120315071946,
#  -0.011092966573830673,
#  0.009648603518856994,
#  -0.03276491582406315,
#  0.00905654498628743,
#  -0.02053337385961358,
#  -0.0037182581652768294,
#  -0.003516567918967152,
#  0.008236771561858605,
#  -0.0015923774552854227,
#  0.005699377584754021,
#  0.010878264121161526,
#  -0.024072712615840843,
#  0.018399359909467054,
#  0.010832720583996121,
#  -0.009433901066187848,
#  0.0356276151929851,
#  -0.006772890313761046,
#  0.002595949254968164,
#  -0.017449463024459662,
#  0.012081899845085828,
#  -0.006216615523303007,
#  -0.011424779116565685,
#  0.02236810543367779,
#  -0.013897111829042278,
#  -0.014053259236678491,
#  -0.03089114693242859,
#  -0.013701928035158305,
#  -0.02852291093950516,
#  -0.0027293251268523215,
#  -0.019323231916094218,
#  -0.0168378876957501,
#  -0.017800795157302433,
#  0.01989577178987861,
#  0.002192568762348809,
#  -0.01891985188913616,
#  -0.0013768616087515707,
#  -0.018516469999532922,
#  -0.02150929376035603,
#  -0.003256322394793894,
#  -0.01630438327689088,
#  0.020403251330357596,
#  0.013936149146612625,
#  0.0015622865389042506,
#  0.014027235289620847,
#  -0.018100077533384745,
#  -0.01882876481480535,
#  0.0012060754398571243,
#  0.01291468477738218,
#  -0.004873097940730137,
#  0.023903552769014517,
#  0.22485214778685586,
#  -0.01157442030460684,
#  -0.010917300507409286,
#  0.04819747498844215,
#  0.013571805505902323,
#  0.013441682045323753,
#  0.026545046259640024,
#  0.009264741219361518,
#  -0.006483367267071322,
#  0.021418208548670395,
#  -0.016994033240741137,
#  0.003565363867438145,
#  -0.011197064224706423,
#  0.012159973548903934,
#  0.009746195881460274,
#  -0.0022169668529996287,
#  -0.032921061369054185,
#  -0.01833429957616165,
#  -0.023174865487593913,
#  -0.022107858512520652,
#  -0.011118990520888317,
#  -0.007631700590098925,
#  -0.025907444189905055,
#  0.012882154610729479,
#  0.038646463832188435,
#  9.657549658111691e-05,
#  -0.01368891559596819,
#  0.01039680945906277,
#  0.012836611073564074,
#  -0.0011629723171164832,
#  -0.013884099389852163,
#  -0.03224442198174887,
#  0.0085230414987508,
#  0.019036961979202023,
#  -0.0005143915838914716,
#  -0.003192887452234021,
#  0.008952446404089091,
#  0.01225105876058957,
#  0.017982967443318877,
#  0.0004027706509476418,
#  -0.014508689020397016,
#  0.0009011001798367996,
#  0.0028740866501971835,
#  -0.025803346539029305,
#  -0.0097266772226751,
#  0.0015964437261170104,
#  ...]

# %%
word = embedder.embed_query("Hi")

len(word)
# Out:
# 1536

# %%
vector = embedder.embed_documents([
    "hi",
    "how",
    "are",
    "you longer sentences because"
])

# %%
print(len(vector), len(vector[0]))
# Out:
# 4 1536

# %%
from dotenv import load_dotenv

load_dotenv()

from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma

splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator="\n",
    chunk_size=600,
    chunk_overlap=100,
)
# chunk_size를 기준으로 자르기때문에 문장 중간이 잘린다.
# loader = UnstructuredFileLoader("./files/temp.txt")
loader = UnstructuredFileLoader("./files/chapter_one.txt")

docs = loader.load_and_split(text_splitter=splitter)

embeddings = OpenAIEmbeddings()

vectorstore = Chroma.from_documents(docs, embeddings)

# %%
result = vectorstore.similarity_search("Where does winston live")

len(result)
# Out:
# 4

# %%
from dotenv import load_dotenv

load_dotenv()

from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings, CacheBackedEmbeddings
from langchain.vectorstores import Chroma
from langchain.storage import LocalFileStore

cache_dir = LocalFileStore("./.cache/")

splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator="\n",
    chunk_size=600,
    chunk_overlap=100,
)

# loader = UnstructuredFileLoader("./files/temp.txt")
loader = UnstructuredFileLoader("./files/chapter_one.txt")

docs = loader.load_and_split(text_splitter=splitter)

embeddings = OpenAIEmbeddings()

cache_embeddings = CacheBackedEmbeddings.from_bytes_store(
    embeddings,
    cache_dir,
)

vectorstore = Chroma.from_documents(docs, cache_embeddings)

# %%
result = vectorstore.similarity_search("Where does winston live")

# %%
len(result)
# Out:
# 4

# %% [markdown]
# # 6.5 Langsmith

# %% [markdown]
# # 6.6 RetrievalQA (18:22)

# %%
from dotenv import load_dotenv
load_dotenv()

from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings, CacheBackedEmbeddings
from langchain.vectorstores import Chroma
from langchain.storage import LocalFileStore
from langchain.chains import RetrievalQA

llm = ChatOpenAI()

cache_dir = LocalFileStore("./.cache/")

splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator="\n",
    chunk_size=600,
    chunk_overlap=100,
)

# loader = UnstructuredFileLoader("./files/temp.txt")
loader = UnstructuredFileLoader("./files/chapter_one.txt")

docs = loader.load_and_split(text_splitter=splitter)

embeddings = OpenAIEmbeddings()

cache_embeddings = CacheBackedEmbeddings.from_bytes_store(
    embeddings,
    cache_dir,
)

vectorstore = Chroma.from_documents(docs, cache_embeddings)

chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vectorstore.as_retriever(),
)

chain.run("Where does Winston live?")
# Out:
# 'Winston lives in Victory Mansions.'

# %%
chain.run("Describe Victory Mansions")
# Out:
# 'There is no specific description of Victory Mansions in the given context.'

# %%
chain.run("Who is winston")
# Out:
# 'Winston is the main character in the novel. He is a man named Winston Smith who lives in a dystopian society ruled by a totalitarian regime called the Party.'

# %%
from dotenv import load_dotenv
load_dotenv()

from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings, CacheBackedEmbeddings
from langchain.vectorstores import Chroma
from langchain.storage import LocalFileStore
from langchain.chains import RetrievalQA

llm = ChatOpenAI()

cache_dir = LocalFileStore("./.cache/")

splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator="\n",
    chunk_size=600,
    chunk_overlap=100,
)

# loader = UnstructuredFileLoader("./files/temp.txt")
loader = UnstructuredFileLoader("./files/chapter_one.txt")

docs = loader.load_and_split(text_splitter=splitter)

embeddings = OpenAIEmbeddings()

cache_embeddings = CacheBackedEmbeddings.from_bytes_store(
    embeddings,
    cache_dir,
)

vectorstore = Chroma.from_documents(docs, cache_embeddings)

chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="refine",
    retriever=vectorstore.as_retriever(),
)

chain.run("Where does Winston live?")
# Out:
# 'In the context provided, Winston Smith lives in Victory Mansions, which is likely located in a dystopian city controlled by the Party.'

# %%
chain.run("Describe Victory Mansions")
# Out:
# "Based on the new context, Victory Mansions can be further described as a dilapidated residential building located in London, specifically in Airstrip One, which is a province of Oceania. The building itself is in a state of disrepair, with rotting nineteenth-century houses patched with cardboard and timber. The surroundings are grim, with bombed sites and sordid colonies of wooden dwellings resembling chicken-houses.\n\nInside Victory Mansions, the living-room contains an unusual arrangement with the telescreen positioned on the longer wall, opposite the window. There is a shallow alcove to one side, potentially intended for bookshelves. Winston, the protagonist, sits in this alcove to remain outside the range of the telescreen's sight, although he can still be heard. The unusual geography of the room has allowed Winston to contemplate his actions, which were inspired by a peculiarly beautiful book he recently acquired.\n\nThe book, found in a frowsy little junk-shop in a slummy quarter of the town, is old and made of smooth creamy paper that hasn't been manufactured for at least forty years. Winston was immediately drawn to it and purchased it despite Party members being discouraged from visiting ordinary shops. The book, even without any writing, is considered a compromising possession. This suggests that Victory Mansions is not only a decaying building but also a place where Party members engage in forbidden activities, seeking items that are not sanctioned by the government."

# %%
from dotenv import load_dotenv
load_dotenv()

from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings, CacheBackedEmbeddings
# 벡터 스토어에 따라 성능이 달라지기도 한다. 
from langchain.vectorstores import FAISS
from langchain.storage import LocalFileStore
from langchain.chains import RetrievalQA

llm = ChatOpenAI()

cache_dir = LocalFileStore("./.cache/")

splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator="\n",
    chunk_size=600,
    chunk_overlap=100,
)

# loader = UnstructuredFileLoader("./files/temp.txt")
loader = UnstructuredFileLoader("./files/chapter_one.txt")

docs = loader.load_and_split(text_splitter=splitter)

embeddings = OpenAIEmbeddings()

cache_embeddings = CacheBackedEmbeddings.from_bytes_store(
    embeddings,
    cache_dir,
)

vectorstore = FAISS.from_documents(docs, cache_embeddings)

chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="refine",
    retriever=vectorstore.as_retriever(),
)

chain.run("Describe Victory Mansions")
# Out:
# 'Victory Mansions, where Winston Smith resides, is a dilapidated and unpleasant building situated in London, the chief city of Airstrip One, a province of Oceania. The building is surrounded by rotting nineteenth-century houses that are supported with timber and patched with cardboard. The roofs are made of corrugated iron, and the garden walls sag in various directions. The bombed sites nearby are covered in plaster dust, with willow-herb growing over the rubble. In some areas, wooden dwellings resembling chicken houses have emerged due to the destruction caused by bombs. From the roof of Victory Mansions, one can see the Ministry of Truth, an enormous pyramidal structure made of white concrete that towers 300 meters into the air. The Ministry of Truth is one of the four Ministries that govern Oceania, with the others being the Ministry of Peace, the Ministry of Love, and the Ministry of Plenty. The building is adorned with the Party\'s slogans: "WAR IS PEACE," "FREEDOM IS SLAVERY," and "IGNORANCE IS STRENGTH."\n\nInside Victory Mansions, Winston has discovered a unique hiding spot in a shallow alcove near the telescreen, which is placed unusually on the longer wall instead of the end wall. By sitting in this alcove and staying well back, Winston can remain outside the range of the telescreen\'s sight, although he can still be heard. It is in this alcove that he finds solace and privacy, allowing him to engage in secret activities that go against the Party\'s surveillance. One such activity involves a book that he purchased from a junk shop in a forbidden area of the city. The book, with its smooth creamy paper and old age, is a rare possession that Winston feels compelled to own, even though he initially has no specific purpose for it. This book becomes a symbol of rebellion and a threat to the Party\'s control, making Victory Mansions a place where Winston\'s private resistance against the oppressive regime takes shape.'

# %% [markdown]
# # 6.7 Recap (05:17)

# %% [markdown]
# # 6.8 Stuff LCEL Chain (10:13)

# %%
from dotenv import load_dotenv

load_dotenv()

from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings, CacheBackedEmbeddings

# 벡터 스토어에 따라 성능이 달라지기도 한다.
from langchain.vectorstores import FAISS
from langchain.storage import LocalFileStore
from langchain.prompts import ChatPromptTemplate

llm = ChatOpenAI(temperature=0.1)

cache_dir = LocalFileStore("./.cache/")

splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator="\n",
    chunk_size=600,
    chunk_overlap=100,
)

# loader = UnstructuredFileLoader("./files/temp.txt")
loader = UnstructuredFileLoader("./files/chapter_one.txt")

docs = loader.load_and_split(text_splitter=splitter)

embeddings = OpenAIEmbeddings()

cache_embeddings = CacheBackedEmbeddings.from_bytes_store(
    embeddings,
    cache_dir,
)

vectorstore = FAISS.from_documents(docs, cache_embeddings)

retriver = vectorstore.as_retriever()

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a helpful assistant. Answer question using only the following context. If you don't Know the answer just say you don't know, don't make it up:\n\n{context}",
        ),
        ("human", "{question}"),
    ]
)

chain = retriver | prompt | llm

chain.invoke("Describe Victory Mansions")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 53
#      41 prompt = ChatPromptTemplate.from_messages(
#      42     [
#      43         (
#    (...)
#      48     ]
#      49 )
#      51 chain = retriver | prompt | llm
# ---> 53 chain.invoke("Describe Victory Mansions")
#
# File ~/anaconda3/envs/clone_gpt_plugin/lib/python3.11/site-packages/langchain/schema/runnable/base.py:1213, in RunnableSequence.invoke(self, input, config)
#    1211 try:
#    1212     for i, step in enumerate(self.steps):
# -> 1213         input = step.invoke(
#    1214             input,
#    1215             # mark each step as a child run
#    1216             patch_config(
#    1217                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    1218             ),
#    1219         )
#    1220 # finish the root run
#    1221 except BaseException as e:
#
# File ~/anaconda3/envs/clone_gpt_plugin/lib/python3.11/site-packages/langchain/schema/prompt_template.py:60, in BasePromptTemplate.invoke(self, input, config)
#      57 def invoke(
#      58     self, input: Dict, config: Optional[RunnableConfig] = None
#      59 ) -> PromptValue:
# ---> 60     return self._call_with_config(
#      61         lambda inner_input: self.format_prompt(
#      62             **{key: inner_input[key] for key in self.input_variables}
#      63         ),
#      64         input,
#      65         config,
#      66         run_type="prompt",
#      67     )
#
# File ~/anaconda3/envs/clone_gpt_plugin/lib/python3.11/site-packages/langchain/schema/runnable/base.py:715, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#     708 run_manager = callback_manager.on_chain_start(
#     709     dumpd(self),
#     710     input,
#     711     run_type=run_type,
#     712     name=config.get("run_name"),
#     713 )
#     714 try:
# --> 715     output = call_func_with_variable_args(
#     716         func, input, config, run_manager, **kwargs
#     717     )
#     718 except BaseException as e:
#     719     run_manager.on_chain_error(e)
#
# File ~/anaconda3/envs/clone_gpt_plugin/lib/python3.11/site-packages/langchain/schema/runnable/config.py:308, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     306 if run_manager is not None and accepts_run_manager(func):
#     307     kwargs["run_manager"] = run_manager
# --> 308 return func(input, **kwargs)
#
# File ~/anaconda3/envs/clone_gpt_plugin/lib/python3.11/site-packages/langchain/schema/prompt_template.py:62, in BasePromptTemplate.invoke.<locals>.<lambda>(inner_input)
#      57 def invoke(
#      58     self, input: Dict, config: Optional[RunnableConfig] = None
#      59 ) -> PromptValue:
#      60     return self._call_with_config(
#      61         lambda inner_input: self.format_prompt(
# ---> 62             **{key: inner_input[key] for key in self.input_variables}
#      63         ),
#      64         input,
#      65         config,
#      66         run_type="prompt",
#      67     )
#
# File ~/anaconda3/envs/clone_gpt_plugin/lib/python3.11/site-packages/langchain/schema/prompt_template.py:62, in <dictcomp>(.0)
#      57 def invoke(
#      58     self, input: Dict, config: Optional[RunnableConfig] = None
#      59 ) -> PromptValue:
#      60     return self._call_with_config(
#      61         lambda inner_input: self.format_prompt(
# ---> 62             **{key: inner_input[key] for key in self.input_variables}
#      63         ),
#      64         input,
#      65         config,
#      66         run_type="prompt",
#      67     )
#
# TypeError: list indices must be integers or slices, not str

# %%
from dotenv import load_dotenv

load_dotenv()

from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings, CacheBackedEmbeddings

# 벡터 스토어에 따라 성능이 달라지기도 한다.
from langchain.vectorstores import FAISS
from langchain.storage import LocalFileStore
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnablePassthrough

llm = ChatOpenAI(temperature=0.1)

cache_dir = LocalFileStore("./.cache/")

splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator="\n",
    chunk_size=600,
    chunk_overlap=100,
)

# loader = UnstructuredFileLoader("./files/temp.txt")
loader = UnstructuredFileLoader("./files/chapter_one.txt")

docs = loader.load_and_split(text_splitter=splitter)

embeddings = OpenAIEmbeddings()

cache_embeddings = CacheBackedEmbeddings.from_bytes_store(
    embeddings,
    cache_dir,
)

vectorstore = FAISS.from_documents(docs, cache_embeddings)

retriver = vectorstore.as_retriever()

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a helpful assistant. Answer question using only the following context. If you don't Know the answer just say you don't know, don't make it up:\n\n{context}",
        ),
        ("human", "{question}"),
    ]
)

chain = (
    {
        "context": retriver,
        "question": RunnablePassthrough(),
        "extra": RunnablePassthrough(),
    }
    | prompt
    | llm
)

chain.invoke("Describe Victory Mansions")
# Out:
# AIMessage(content='Victory Mansions is a building where Winston Smith resides. It is described as having glass doors at the entrance, which allow gritty dust to enter along with people. The hallway of Victory Mansions has a smell of boiled cabbage and old rag mats. There is a large colored poster on one end of the hallway, depicting the face of a man in his forties with a black mustache. The building has seven floors, and the elevator is often out of service due to the electricity being cut off during daylight hours. The walls of the building have posters with the slogan "BIG BROTHER IS WATCHING YOU." Overall, Victory Mansions is portrayed as a grimy and dilapidated place.')

# %%
from dotenv import load_dotenv

load_dotenv()

from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings, CacheBackedEmbeddings

# 벡터 스토어에 따라 성능이 달라지기도 한다.
from langchain.vectorstores import FAISS
from langchain.storage import LocalFileStore
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnablePassthrough

llm = ChatOpenAI(temperature=0.1)

cache_dir = LocalFileStore("./.cache/")

splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator="\n",
    chunk_size=600,
    chunk_overlap=100,
)

# loader = UnstructuredFileLoader("./files/temp.txt")
loader = UnstructuredFileLoader("./files/chapter_one.txt")

docs = loader.load_and_split(text_splitter=splitter)

embeddings = OpenAIEmbeddings()

cache_embeddings = CacheBackedEmbeddings.from_bytes_store(
    embeddings,
    cache_dir,
)

vectorstore = FAISS.from_documents(docs, cache_embeddings)

retriver = vectorstore.as_retriever()

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a helpful assistant. Answer question using only the following context. If you don't Know the answer just say you don't know, don't make it up:\n\n{context}",
        ),
        ("human", "{question}"),
    ]
)

chain = (
    {
        "context": retriver,
        "question": RunnablePassthrough(),
    }
    | prompt
    | llm
)

chain.invoke("Describe Victory Mansions")
# Out:
# AIMessage(content='Victory Mansions is a building where Winston Smith resides. It is described as having glass doors at the entrance, which allow gritty dust to enter along with people. The hallway of Victory Mansions has a smell of boiled cabbage and old rag mats. There is a large colored poster on one end of the hallway, depicting the face of a man in his forties with a black mustache. The building has seven floors, and the lift is often not working due to the electricity being cut off during daylight hours. The poster with the enormous face and the slogan "BIG BROTHER IS WATCHING YOU" is displayed on each landing opposite the lift-shaft.')

# %% [markdown]
# # 6.9 Map Reduce LCEL Chain (19:48)

# %%
from dotenv import load_dotenv

load_dotenv()

from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings, CacheBackedEmbeddings

# 벡터 스토어에 따라 성능이 달라지기도 한다.
from langchain.vectorstores import FAISS
from langchain.storage import LocalFileStore
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnablePassthrough, RunnableLambda

llm = ChatOpenAI(temperature=0.1)

cache_dir = LocalFileStore("./.cache/")

splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator="\n",
    chunk_size=600,
    chunk_overlap=100,
)

# loader = UnstructuredFileLoader("./files/temp.txt")
loader = UnstructuredFileLoader("./files/chapter_one.txt")

docs = loader.load_and_split(text_splitter=splitter)

embeddings = OpenAIEmbeddings()

cache_embeddings = CacheBackedEmbeddings.from_bytes_store(
    embeddings,
    cache_dir,
)

vectorstore = FAISS.from_documents(docs, cache_embeddings)

retriver = vectorstore.as_retriever()

# prompt = ChatPromptTemplate.from_messages(
#     [
#         (
#             "system",
#             "You are a helpful assistant. Answer question using only the following context. If you don't Know the answer just say you don't know, don't make it up:\n\n{context}",
#         ),
#         ("human", "{question}"),
#     ]
# )

# list of docs

# for doc in list of docs | prompt | llm

# for response in list of response | put them all together

# final doc | prompt | llm

map_doc_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
            Use the following portion of a long document to see if any of the 
            text is relavant to answer the question. Return any relevant text
            verbatim.
            ------
            {context}
            """,
        ),
        ("human", "{question}"),
    ]
)

map_doc_chain = map_doc_prompt | llm


# list of docs


def map_docs(inputs):
    documents = inputs["documents"]
    question = inputs["question"]
    # results = []
    # for document in documents:
    #     result = map_doc_chain.invoke(
    #         {"context": document.page_content, "question": question}
    #     ).content
    #     results.append(result)
    #     results = "\n\n".join(results)
    # return results
    return "\n\n".join(
        map_doc_chain.invoke(
            {"context": doc.page_content, "question": question}
        ).content
        for doc in documents
    )


map_chain = {
    "documents": retriver,
    "question": RunnablePassthrough(),
} | RunnableLambda(map_docs)

# final doc | prompt | llm

final_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
            Given the following extracted parts of a long document and a
            question, create a final answer.
            If you don't know the answer, just say that you don't know. Don't try
            to make up an answer.
            ----
            {context}
            """,
        ),
        ("human", "{question}"),
    ]
)

chain = {"context": map_chain, "question": RunnablePassthrough()} | final_prompt | llm

chain.invoke("Describe Victory Mansions")
# Out:
# AIMessage(content='Victory Mansions is a building complex located in London, specifically in Airstrip One, which is the chief city of Oceania. It is described as a grimy landscape with rotting nineteenth-century houses. The houses are in a state of disrepair, with their sides supported by timber, windows patched with cardboard, and roofs made of corrugated iron. The garden walls are sagging in all directions. There are also bombed sites with rubble and plaster dust in the air, and in some areas, sordid colonies of wooden dwellings resembling chicken-houses have sprung up.\n\nInside Victory Mansions, there is a hallway with glass doors that Winston Smith enters. The hallway has a smell of boiled cabbage and old rag mats. On one end of the hallway, there is a large colored poster depicting the face of a man in his forties with a black mustache. The building has seven flights of stairs, as the lift is often not working. On each landing, there is a poster with the caption "BIG BROTHER IS WATCHING YOU."\n\nOnce inside the flat, there is a telescreen, an oblong metal plaque that cannot be completely shut off, which is reading out a list of figures related to pig-iron production. The telescreen is positioned unusually in the living-room, not in the end wall as normal, but in the longer wall opposite the window. There is a shallow alcove next to the telescreen, likely intended for bookshelves. By sitting in this alcove, Winston can avoid being seen by the telescreen, although he can still be heard. The unique layout of the room has inspired Winston to take a certain action.')

# %%
chain.invoke("Where does Winston go to work")
# Out:
# AIMessage(content='The given portion of the document does not mention where Winston goes to work.')

# %% [markdown]
# # 6.10 Recap (07:26)
